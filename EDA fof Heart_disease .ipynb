# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns

# %%
column_name = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df = pd.read_csv('C:/Users/biplo/Downloads/Heart_disease_cl.csv',header = None, names = column_name)

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
# count plot 
sns.countplot(data=df, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['exang'].value_counts()
# Out:
# exang
# 0    204
# 1     99
# Name: count, dtype: int64

# %%
#pie chart
df['sex'].value_counts().plot(kind='pie',autopct='%0.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# Histogram
plt.hist(df['chol'])
# Out:
# (array([ 12.,  72., 106.,  69.,  36.,   3.,   4.,   0.,   0.,   1.]),
#  array([126. , 169.8, 213.6, 257.4, 301.2, 345. , 388.8, 432.6, 476.4,
#         520.2, 564. ]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot
# probability density function --> The line is kde
# skweness
sns.distplot(df['chol'])
# Out:
# C:\Users\biplo\AppData\Local\Temp\ipykernel_2760\2473448194.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['chol'])
# <Axes: xlabel='chol', ylabel='Density'>

# %%
#Box plot 
sns.boxplot(df['chol'])
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope         num
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
# Scatter plot(Numerical - Numerical) for the relation between two column
sns.scatterplot(x='age', y='chol',hue='sex', style='restecg',size='trestbps' ,data=df)
plt.show()

# %%
  # Bar plot 
sns.barplot(x='sex',y='chol',hue='ca',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
#Box plot 

sns.boxplot(x='sex',y='chol',hue='ca',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
# Displot

sns.distplot(df[df['sex']==0]['age'],hist=False)
sns.distplot(df[df['sex']==1]['age'],hist=False)
# Out:
# C:\Users\biplo\AppData\Local\Temp\ipykernel_2760\2552899196.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['sex']==0]['age'],hist=False)
# C:\Users\biplo\AppData\Local\Temp\ipykernel_2760\2552899196.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#Heatma[p]
sns.heatmap(pd.crosstab(df['fbs'],df['sex']))
# Out:
# <Axes: xlabel='sex', ylabel='fbs'>

# %%
#pairplot
sns.pairplot(df,hue='fbs')
# Out:
# D:\Projrct1\anacondafiles\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#line plot
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.heatmap(df.pivot_table(values='chol',index='sex',columns='age'))
# Out:
# <Axes: xlabel='age', ylabel='sex'>
